# %%
from code.neuron import *
from code.encodingsource import *
from code.hsgs import *
from code.classical_neuron import *
from code.classical_pso import *
from code.sf import *
simulator = Aer.get_backend('qasm_simulator')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from code.experiment_functions import *

# %%
diabetes = pd.read_csv('data/diabetes.csv')

# %%
# normalization 0-1
for i in diabetes.columns:
    diabetes[i] = (diabetes[i] - diabetes[i].min()) / (diabetes[i].max() - diabetes[i].min())

# %%
# split in test and train data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(diabetes.drop('Outcome',axis=1), diabetes['Outcome'])

# %%
X_train = X_train.values.tolist()
X_test = X_test.values.tolist()
y_train = y_train.values.tolist()
y_test = y_test.values.tolist()

# %%
y_train = [int(x) for x in y_train]
y_test =  [int(x) for x in y_test]

# %% [markdown]
# ### Train and Test with Bias

# %%
epoch_errosHSGS, epoch_errosEncodingWeight, epoch_errosEncodingInput, epoch_errosPhaseEncoding  = experiment_TRAIN(X_train, 
                                                                                         y_train,
                                                                                         lrParameter=0.2, 
                                                                                         n_epochs=20, 
                                                                                         trainingBias=True,
                                                                                         error_by_epoch = False,
                                                                                         trainingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'encoding-input', 'phase-encoding'})

# %%
with open('results/version4/error_by_epoch_unbiased.json', 'w+') as fp:
    json.dump({'epoch_errosHSGS': epoch_errosHSGS,
               'epoch_errosEncodingWeight': epoch_errosEncodingWeight, 
               'epoch_errosPhaseEncoding': epoch_errosPhaseEncoding, 
               'epoch_errosEncodingInput': epoch_errosEncodingInput},
              fp)

# %%
weightsEncodingWeight, weightsEncodingInput, weightsPhaseEncoding, weightsHSGS, weightsVectorsClassico, weightVectorsClassicoBin = experiment_TRAIN(X_train, 
                                                                                                             y_train,
                                                                                                             lrParameter=0.2, 
                                                                                                             n_epochs=20, 
                                                                                                             trainingBias=False,
                                                                                                             trainingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'encoding-input', 'phase-encoding'})
# Out:
# erro HSGS 10.2197265625
# erro encoding weight 505.7900390625
# erro encoding input 317.8076171875
# erro phase encoding 174.3466796875
# erro classico 88.6180606738132
# erro classico Bin 212.65483554319545
#
# erro HSGS 0.0
# erro encoding weight 507.6513671875
# erro encoding input 318.189453125
# erro phase encoding 184.5244140625
# erro classico 74.28810022119933
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.501953125
# erro encoding input 317.7412109375
# erro phase encoding 184.416015625
# erro classico 74.28873214639039
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.5634765625
# erro encoding input 317.6220703125
# erro phase encoding 184.46484375
# erro classico 74.28873280953874
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.7021484375
# erro encoding input 318.2890625
# erro phase encoding 184.3583984375
# erro classico 74.28873281027232
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.716796875
# erro encoding input 318.4384765625
# erro phase encoding 184.458984375
# erro classico 74.2887328102571
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.8876953125
# erro encoding input 318.4169921875
# erro phase encoding 184.458984375
# erro classico 74.28873281024087
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.5009765625
# erro encoding input 318.0771484375
# erro phase encoding 184.27734375
# erro classico 74.28873281028206
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.6103515625
# erro encoding input 318.5390625
# erro phase encoding 184.322265625
# erro classico 74.28873281024505
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.81640625
# erro encoding input 318.146484375
# erro phase encoding 184.4716796875
# erro classico 74.28873281025291
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.6982421875
# erro encoding input 317.7763671875
# erro phase encoding 185.0888671875
# erro classico 74.28873281027002
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.826171875
# erro encoding input 318.21875
# erro phase encoding 184.6005859375
# erro classico 74.2887328102571
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.791015625
# erro encoding input 317.990234375
# erro phase encoding 184.6318359375
# erro classico 74.28873281024087
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 508.2421875
# erro encoding input 317.3525390625
# erro phase encoding 184.4306640625
# erro classico 74.28873281028206
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.5146484375
# erro encoding input 317.98046875
# erro phase encoding 184.6015625
# erro classico 74.28873281024505
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.4716796875
# erro encoding input 318.4521484375
# erro phase encoding 183.68359375
# erro classico 74.28873281025291
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.744140625
# erro encoding input 317.984375
# erro phase encoding 184.439453125
# erro classico 74.28873281027002
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.849609375
# erro encoding input 317.7802734375
# erro phase encoding 184.7021484375
# erro classico 74.2887328102571
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.40234375
# erro encoding input 318.1201171875
# erro phase encoding 184.154296875
# erro classico 74.28873281024087
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.3125
# erro encoding input 318.3115234375
# erro phase encoding 184.31640625
# erro classico 74.28873281028206
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.3125
# erro encoding input 318.3115234375
# erro phase encoding 184.31640625
# erro Classico 74.28873281028206
# erro classico Bin 205.94105390216203

# %%
weights = [weightsEncodingWeight, 
          weightsEncodingInput, 
          weightsPhaseEncoding, 
          weightsHSGS, 
          weightsVectorsClassico, 
          weightVectorsClassicoBin]

# %%
with open('results/version4/weights_unbiased_v4.json', 'w+') as fp:
    json.dump(weights, fp)

# %% [markdown]
# #### Test

# %%
with open('results/version4/weights_unbiased_v4.json') as json_file:
    weights = json.load(json_file)

# %%
resultsBIAS = experiment_TEST(X_test, 
                              y_test, 
                              weights[0], 
                              weights[1], 
                              weights[2], 
                              weights[3], 
                              weights[4], 
                              weights[5], 
                              repeat=10,
                              bias=False, 
                              testingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'phase-encoding','encoding-input'})
# Out:
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5052083333333334
# erro phase encoding 0.5104166666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5208333333333334
# erro phase encoding 0.5416666666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5416666666666666
# erro phase encoding 0.5208333333333334
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.65625
# erro encoding input 0.515625
# erro phase encoding 0.5364583333333334
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6614583333333334
# erro encoding input 0.5520833333333334
# erro phase encoding 0.546875
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.65625
# erro encoding input 0.5364583333333334
# erro phase encoding 0.5104166666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.4947916666666667
# erro phase encoding 0.5364583333333334
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.671875
# erro encoding input 0.5104166666666666
# erro phase encoding 0.53125
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.3854166666666667
# erro phase encoding 0.546875
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6614583333333334
# erro encoding input 0.5364583333333334
# erro phase encoding 0.5572916666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# ERROS HSGS             0.3645999999999999
# ERROS ENCODING WEIGHT  0.66408
# ERROS ENCODING INPUT   0.5098999999999999
# ERROS PHASE ENCODING   0.53386
# ERROS Classico         0.41669999999999996
# ERROS Classico Bin     0.3645999999999999

# %%
with open('results/version4/experiments_unbiased.json', 'w+') as fp:
    json.dump(resultsBIAS, fp)

# %% [markdown]
# ## Save results as dataframe

# %%
def readAndResults(i):
    with open('results/'+i) as f:
        data = json.load(f)

    erros = ['error_HSGS', 'error_encoding_weight', 'error_encoding_input', 'error_phase_encoding']
    new_data = {'error':[], 'model':[]}

    for erro in erros:
        new_data['error'] = new_data['error'] + data[erro] 
        new_data['model'] = new_data['model'] +  ( (erro+' ') * len(data[erro])).split(' ')[:-1]  

    new_data = pd.DataFrame(new_data)

    new_data.to_csv('results/'+i[:-5]+'_dataframe.csv', index=False)
    
    return new_data

# %%
readAndResults('version4/experiments_unbiased.json')
# Out:
#      error                  model
# 0   0.3646             error_HSGS
# 1   0.3646             error_HSGS
# 2   0.3646             error_HSGS
# 3   0.3646             error_HSGS
# 4   0.3646             error_HSGS
# 5   0.3646             error_HSGS
# 6   0.3646             error_HSGS
# 7   0.3646             error_HSGS
# 8   0.3646             error_HSGS
# 9   0.3646             error_HSGS
# 10  0.6667  error_encoding_weight
# 11  0.6667  error_encoding_weight
# 12  0.6667  error_encoding_weight
# 13  0.6562  error_encoding_weight
# 14  0.6615  error_encoding_weight
# 15  0.6562  error_encoding_weight
# 16  0.6667  error_encoding_weight
# 17  0.6719  error_encoding_weight
# 18  0.6667  error_encoding_weight
# 19  0.6615  error_encoding_weight
# 20  0.5052   error_encoding_input
# 21  0.5208   error_encoding_input
# 22  0.5417   error_encoding_input
# 23  0.5156   error_encoding_input
# 24  0.5521   error_encoding_input
# 25  0.5365   error_encoding_input
# 26  0.4948   error_encoding_input
# 27  0.5104   error_encoding_input
# 28  0.3854   error_encoding_input
# 29  0.5365   error_encoding_input
# 30  0.5104   error_phase_encoding
# 31  0.5417   error_phase_encoding
# 32  0.5208   error_phase_encoding
# 33  0.5365   error_phase_encoding
# 34  0.5469   error_phase_encoding
# 35  0.5104   error_phase_encoding
# 36  0.5365   error_phase_encoding
# 37  0.5312   error_phase_encoding
# 38  0.5469   error_phase_encoding
# 39  0.5573   error_phase_encoding
