# %%
from code.neuron import *
from code.encodingsource import *
from code.hsgs import *
from code.classical_neuron import *
from code.classical_pso import *
from code.sf import *
simulator = Aer.get_backend('qasm_simulator')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from code.experiment_functions import *

# %%
diabetes = pd.read_csv('data/diabetes.csv')

# %%
# normalization 0-1
for i in diabetes.columns:
    diabetes[i] = (diabetes[i] - diabetes[i].min()) / (diabetes[i].max() - diabetes[i].min())

# %%
# split in test and train data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(diabetes.drop('Outcome',axis=1), diabetes['Outcome'])

# %%
X_train = X_train.values.tolist()
X_test = X_test.values.tolist()
y_train = y_train.values.tolist()
y_test = y_test.values.tolist()

# %%
y_train = [int(x) for x in y_train]
y_test =  [int(x) for x in y_test]

# %% [markdown]
# ### Train and Test with Bias

# %%
epoch_errosHSGS, epoch_errosEncodingWeight, epoch_errosEncodingInput, epoch_errosPhaseEncoding  = experiment_TRAIN(X_train, 
                                                                                         y_train,
                                                                                         lrParameter=0.2, 
                                                                                         n_epochs=20, 
                                                                                         trainingBias=True,
                                                                                         error_by_epoch = False,
                                                                                         trainingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'encoding-input', 'phase-encoding'})
# Out:
# erro HSGS 8.2275390625
# erro encoding weight 332.1474609375
# erro encoding input 182.3525390625
# erro phase encoding 72.8701171875
# erro classico 21.800604746665947
# erro classico Bin 150.1796233262912
#
# erro HSGS 0.0
# erro encoding weight 330.87109375
# erro encoding input 181.21484375
# erro phase encoding 74.3642578125
# erro classico 11.836733653224373
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.4404296875
# erro encoding input 181.1064453125
# erro phase encoding 73.865234375
# erro classico 11.83895421034015
# erro classico Bin 145.7823554784469
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3b656e30e214> in <module>
#       5                                                                                          trainingBias=True,
#       6                                                                                          error_by_epoch = False,
# ----> 7                                                                                          trainingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'encoding-input', 'phase-encoding'})
#
# ~/quantumML-health/code/experiment_functions.py in experiment_TRAIN(Xs_train, ys_train, lrParameter, n_epochs, seed, trainingBias, trainingApproaches, error_by_epoch, epoch_results)
#     219                                                         weightVector = weightVectorsEncodingWeight[y_train],
#     220                                                         y_train=1,
# --> 221                                                         lrParameter=lrParameter)
#     222
#     223                 norm = np.linalg.norm(weightVectorsEncodingWeight[y_train])
#
# ~/quantumML-health/code/experiment_functions.py in treinamentoNeuronio(operator, inputVector, weightVector, y_train, lrParameter)
#      32         inputBinary = thresholdBinarization(inputVector) # Binarization of Real inputs
#      33         neuron = createNeuron(inputBinary, weightVector, operator)
# ---> 34         resultado = executeNeuron(neuron, simulator, threshold=None)
#      35         deltaRule(inputVector, weightVector, lr=lrParameter, y_train=y_train, out=resultado)
#      36         return resultado
#
# ~/quantumML-health/code/neuron.py in executeNeuron(neuronQuantumCircuit, simulator, threshold, nshots)
#     122     neuronOutput = int # FARIA MAI SENTIDO ISSO SER TRUE OU FALSE
#     123     circuit = neuronQuantumCircuit
# --> 124     job = execute(circuit, backend=simulator, shots=nshots)
#     125     result = job.result()
#     126     count = result.get_counts()
#
# /opt/conda/lib/python3.7/site-packages/qiskit/execute.py in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     257                                 seed_transpiler=seed_transpiler,
#     258                                 optimization_level=optimization_level,
# --> 259                                 backend=backend)
#     260
#     261     if schedule_circuit:
#
# /opt/conda/lib/python3.7/site-packages/qiskit/compiler/transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     241
#     242     # Transpile circuits in parallel
# --> 243     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     244
#     245     end_time = time()
#
# /opt/conda/lib/python3.7/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     104         return []
#     105     if len(values) == 1:
# --> 106         return [task(values[0], *task_args, **task_kwargs)]
#     107
#     108     Publisher().publish("terra.parallel.start", len(values))
#
# /opt/conda/lib/python3.7/site-packages/qiskit/compiler/transpile.py in _transpile_circuit(circuit_config_tuple)
#     325
#     326     result = pass_manager.run(circuit, callback=transpile_config['callback'],
# --> 327                               output_name=transpile_config['output_name'])
#     328
#     329     if transpile_config['faulty_qubits_map']:
#
# /opt/conda/lib/python3.7/site-packages/qiskit/transpiler/passmanager.py in run(self, circuits, output_name, callback)
#     223         """
#     224         if isinstance(circuits, QuantumCircuit):
# --> 225             return self._run_single_circuit(circuits, output_name, callback)
#     226         elif len(circuits) == 1:
#     227             return self._run_single_circuit(circuits[0], output_name, callback)
#
# /opt/conda/lib/python3.7/site-packages/qiskit/transpiler/passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     286         if callback is None and self.callback:  # TODO to remove with __init__(callback)
#     287             callback = self.callback
# --> 288         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     289         self.property_set = running_passmanager.property_set
#     290         return result
#
# /opt/conda/lib/python3.7/site-packages/qiskit/transpiler/runningpassmanager.py in run(***failed resolving arguments***)
#     111         for passset in self.working_list:
#     112             for pass_ in passset:
# --> 113                 dag = self._do_pass(pass_, dag, passset.options)
#     114
#     115         circuit = dag_to_circuit(dag)
#
# /opt/conda/lib/python3.7/site-packages/qiskit/transpiler/runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     142         # Run the pass itself, if not already run
#     143         if pass_ not in self.valid_passes:
# --> 144             dag = self._run_this_pass(pass_, dag)
#     145
#     146             # update the valid_passes property
#
# /opt/conda/lib/python3.7/site-packages/qiskit/transpiler/runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     154             # Measure time if we have a callback or logging set
#     155             start_time = time()
# --> 156             new_dag = pass_.run(dag)
#     157             end_time = time()
#     158             run_time = end_time - start_time
#
# /opt/conda/lib/python3.7/site-packages/qiskit/transpiler/passes/optimization/optimize_1q_gates.py in run(self, dag)
#     237             if right_name == "u":
#     238                 if "u" in self.basis:
# --> 239                     new_op = UGate(*right_parameters)
#     240             if right_name == "u3":
#     241                 if "u3" in self.basis:
#
# /opt/conda/lib/python3.7/site-packages/qiskit/circuit/library/standard_gates/u.py in __init__(self, theta, phi, lam, label)
#      62     def __init__(self, theta, phi, lam, label=None):
#      63         """Create new U gate."""
# ---> 64         super().__init__('u', 1, [theta, phi, lam], label=label)
#      65
#      66     def inverse(self):
#
# /opt/conda/lib/python3.7/site-packages/qiskit/circuit/gate.py in __init__(self, name, num_qubits, params, label)
#      38         self._label = label
#      39         self.definition = None
# ---> 40         super().__init__(name, num_qubits, 0, params)
#      41
#      42     def to_matrix(self) -> np.ndarray:
#
# /opt/conda/lib/python3.7/site-packages/qiskit/circuit/instruction.py in __init__(self, name, num_qubits, num_clbits, params, duration, unit)
#      82         # empty definition means opaque or fundamental instruction
#      83         self._definition = None
# ---> 84         self.params = params
#      85
#      86         self._duration = duration
#
# /opt/conda/lib/python3.7/site-packages/qiskit/circuit/instruction.py in params(self, parameters)
#     143         self._params = []
#     144         for single_param in parameters:
# --> 145             if isinstance(single_param, ParameterExpression):
#     146                 self._params.append(single_param)
#     147             else:
#
# KeyboardInterrupt:

# %%
with open('results/version4/error_by_epoch_unbiased.json', 'w+') as fp:
    json.dump({'epoch_errosHSGS': epoch_errosHSGS,
               'epoch_errosEncodingWeight': epoch_errosEncodingWeight, 
               'epoch_errosPhaseEncoding': epoch_errosPhaseEncoding, 
               'epoch_errosEncodingInput': epoch_errosEncodingInput},
              fp)

# %%
weightsEncodingWeight, weightsEncodingInput, weightsPhaseEncoding, weightsHSGS, weightsVectorsClassico, weightVectorsClassicoBin = experiment_TRAIN(X_train, 
                                                                                                             y_train,
                                                                                                             lrParameter=0.2, 
                                                                                                             n_epochs=20, 
                                                                                                             trainingBias=False,
                                                                                                             trainingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'encoding-input', 'phase-encoding'})
# Out:
# erro HSGS 10.19921875
# erro encoding weight 506.3291015625
# erro encoding input 318.7802734375
# erro phase encoding 175.2587890625
# erro classico 88.6180606738132
# erro classico Bin 212.65483554319545
#
# erro HSGS 0.0
# erro encoding weight 507.87890625
# erro encoding input 318.5244140625
# erro phase encoding 184.681640625
# erro classico 74.28810022119933
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.322265625
# erro encoding input 317.830078125
# erro phase encoding 183.9775390625
# erro classico 74.28873214639039
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.755859375
# erro encoding input 317.4716796875
# erro phase encoding 184.6552734375
# erro classico 74.28873280953874
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.814453125
# erro encoding input 317.697265625
# erro phase encoding 184.1142578125
# erro classico 74.28873281027232
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.583984375
# erro encoding input 318.267578125
# erro phase encoding 184.7880859375
# erro classico 74.2887328102571
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.9580078125
# erro encoding input 318.109375
# erro phase encoding 184.4306640625
# erro classico 74.28873281024087
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.759765625
# erro encoding input 318.4208984375
# erro phase encoding 184.7939453125
# erro classico 74.28873281028206
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 508.017578125
# erro encoding input 318.025390625
# erro phase encoding 183.646484375
# erro classico 74.28873281024505
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.7880859375
# erro encoding input 318.1728515625
# erro phase encoding 184.8525390625
# erro classico 74.28873281025291
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.8857421875
# erro encoding input 318.35546875
# erro phase encoding 184.228515625
# erro classico 74.28873281027002
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.7041015625
# erro encoding input 317.693359375
# erro phase encoding 185.0322265625
# erro classico 74.2887328102571
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.8935546875
# erro encoding input 317.6845703125
# erro phase encoding 184.5244140625
# erro classico 74.28873281024087
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.4052734375
# erro encoding input 318.2412109375
# erro phase encoding 183.98828125
# erro classico 74.28873281028206
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 508.017578125
# erro encoding input 318.232421875
# erro phase encoding 184.83984375
# erro classico 74.28873281024505
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 508.2294921875
# erro encoding input 317.9248046875
# erro phase encoding 185.1064453125
# erro classico 74.28873281025291
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.875
# erro encoding input 317.6181640625
# erro phase encoding 184.0234375
# erro classico 74.28873281027002
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.5625
# erro encoding input 318.0673828125
# erro phase encoding 184.53125
# erro classico 74.2887328102571
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.748046875
# erro encoding input 318.283203125
# erro phase encoding 184.30078125
# erro classico 74.28873281024087
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.4130859375
# erro encoding input 318.005859375
# erro phase encoding 184.5703125
# erro classico 74.28873281028206
# erro classico Bin 205.94105390216203
#
# erro HSGS 0.0
# erro encoding weight 507.4130859375
# erro encoding input 318.005859375
# erro phase encoding 184.5703125
# erro Classico 74.28873281028206
# erro classico Bin 205.94105390216203

# %%
weights = [weightsEncodingWeight, 
          weightsEncodingInput, 
          weightsPhaseEncoding, 
          weightsHSGS, 
          weightsVectorsClassico, 
          weightVectorsClassicoBin]

# %%
with open('results/version4/weights_unbiased_v4.json', 'w+') as fp:
    json.dump(weights, fp)

# %% [markdown]
# #### Test

# %%
with open('results/version4/weights_unbiased_v4.json') as json_file:
    weights = json.load(json_file)

# %%
resultsBIAS = experiment_TEST(X_test, 
                              y_test, 
                              weights[0], 
                              weights[1], 
                              weights[2], 
                              weights[3], 
                              weights[4], 
                              weights[5], 
                              repeat=10,
                              bias=False, 
                              testingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'phase-encoding','encoding-input'})
# Out:
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6614583333333334
# erro encoding input 0.4947916666666667
# erro phase encoding 0.5260416666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5260416666666666
# erro phase encoding 0.4895833333333333
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5572916666666666
# erro phase encoding 0.5208333333333334
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5208333333333334
# erro phase encoding 0.5104166666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6614583333333334
# erro encoding input 0.546875
# erro phase encoding 0.4895833333333333
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5416666666666666
# erro phase encoding 0.515625
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6614583333333334
# erro encoding input 0.4947916666666667
# erro phase encoding 0.515625
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.5052083333333334
# erro phase encoding 0.5104166666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6666666666666666
# erro encoding input 0.4635416666666667
# erro phase encoding 0.5104166666666666
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.6614583333333334
# erro encoding input 0.5572916666666666
# erro phase encoding 0.515625
# erro classico 0.4166666666666667
# erro classico bin 0.3645833333333333
# ERROS HSGS             0.3645999999999999
# ERROS ENCODING WEIGHT  0.66462
# ERROS ENCODING INPUT   0.5208299999999999
# ERROS PHASE ENCODING   0.5104
# ERROS Classico         0.41669999999999996
# ERROS Classico Bin     0.3645999999999999

# %%
with open('results/version4/experiments_unbiased.json', 'w+') as fp:
    json.dump(resultsBIAS, fp)

# %% [markdown]
# ## Save results as dataframe

# %%
resultsBIAS
# Out:
# {'error_HSGS': [0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646],
#  'error_encoding_weight': [0.6615,
#   0.6667,
#   0.6667,
#   0.6667,
#   0.6615,
#   0.6667,
#   0.6615,
#   0.6667,
#   0.6667,
#   0.6615],
#  'error_encoding_input': [0.4948,
#   0.526,
#   0.5573,
#   0.5208,
#   0.5469,
#   0.5417,
#   0.4948,
#   0.5052,
#   0.4635,
#   0.5573],
#  'error_phase_encoding': [0.526,
#   0.4896,
#   0.5208,
#   0.5104,
#   0.4896,
#   0.5156,
#   0.5156,
#   0.5104,
#   0.5104,
#   0.5156],
#  'error_classic': [0.4167,
#   0.4167,
#   0.4167,
#   0.4167,
#   0.4167,
#   0.4167,
#   0.4167,
#   0.4167,
#   0.4167,
#   0.4167],
#  'error_classic_bin': [0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646],
#  'weights_learned_HSGS': [[-0.342738255498,
#    -0.033094685231,
#    -0.487840016467,
#    -0.358462033991,
#    -0.29439616773,
#    -0.442212504808,
#    -0.324137206066,
#    -0.357304334159],
#   [-0.424920801799,
#    -0.415527301164,
#    -0.623022394816,
#    -0.018657999204,
#    -0.31497331883,
#    -0.216644039593,
#    -0.334516189584,
#    -0.015180126798]],
#  'weights_learned_encoding_weight': [[-0.16694010458,
#    -0.565332086787,
#    -0.597213136306,
#    -0.151113455371,
#    -0.036563126355,
#    -0.463906655715,
#    -0.12928823079,
#    -0.199424503295],
#   [-0.285505451953,
#    -0.575062850437,
#    -0.464901470981,
#    -0.28487436249,
#    -0.086953489325,
#    -0.433486718985,
#    -0.183557159926,
#    -0.247664488829]],
#  'weights_learned_encoding_input': [[-0.197341516153,
#    -0.559496903785,
#    -0.593266582724,
#    -0.133050633929,
#    -0.03608027023,
#    -0.460421144566,
#    -0.129398903387,
#    -0.219814328083],
#   [-0.288759141931,
#    -0.590511177869,
#    -0.467105516691,
#    -0.23945870699,
#    -0.077324402506,
#    -0.454386619915,
#    -0.172903031946,
#    -0.223707283409]],
#  'weights_learned_phase_encoding': [[-0.185013300473,
#    -0.56131373796,
#    -0.592466227206,
#    -0.168492482986,
#    -0.053876156239,
#    -0.47222321772,
#    -0.130639156077,
#    -0.16830633487],
#   [-0.277673569679,
#    -0.578484293933,
#    -0.503723926821,
#    -0.227780560076,
#    -0.093869576258,
#    -0.443694512849,
#    -0.178318292405,
#    -0.21250364912]],
#  'weights_learned_classic': [[-0.212813602325,
#    -0.574093000426,
#    -0.54337196346,
#    -0.161862576847,
#    -0.066328916358,
#    -0.463811002147,
#    -0.145191201293,
#    -0.251146087525],
#   [-0.255848149512,
#    -0.578286942551,
#    -0.460766334527,
#    -0.229739550647,
#    -0.092602742116,
#    -0.482870039196,
#    -0.185675141172,
#    -0.242540841204]],
#  'weights_learned_classic_bin': [[-0.167328528401,
#    -0.572193730419,
#    -0.589264760867,
#    -0.143026416914,
#    -0.039259755295,
#    -0.469362231266,
#    -0.128247102853,
#    -0.196510641449],
#   [-0.252629687707,
#    -0.625049134761,
#    -0.464222374414,
#    -0.208763591777,
#    -0.059205698702,
#    -0.46633420978,
#    -0.158504561168,
#    -0.200774908754]]}

# %%
def readAndResults(i):
    with open('results/'+i) as f:
        data = json.load(f)

    erros = ['error_HSGS', 'error_encoding_weight', 'error_encoding_input', 'error_classic', 'error_classic_bin']
    new_data = {'error':[], 'model':[]}

    for erro in erros:
        new_data['error'] = new_data['error'] + data[erro] 
        new_data['model'] = new_data['model'] +  ( (erro+' ') * len(data[erro])).split(' ')[:-1]  

    new_data = pd.DataFrame(new_data)

    new_data.to_csv('results/'+i[:-5]+'_dataframe.csv', index=False)
    
    return new_data

# %%
readAndResults('version4/experiments_unbiased.json')
# Out:
#      error                  model
# 0   0.3646             error_HSGS
# 1   0.3646             error_HSGS
# 2   0.3646             error_HSGS
# 3   0.3646             error_HSGS
# 4   0.3646             error_HSGS
# 5   0.3646             error_HSGS
# 6   0.3646             error_HSGS
# 7   0.3646             error_HSGS
# 8   0.3646             error_HSGS
# 9   0.3646             error_HSGS
# 10  0.6615  error_encoding_weight
# 11  0.6667  error_encoding_weight
# 12  0.6667  error_encoding_weight
# 13  0.6667  error_encoding_weight
# 14  0.6615  error_encoding_weight
# 15  0.6667  error_encoding_weight
# 16  0.6615  error_encoding_weight
# 17  0.6667  error_encoding_weight
# 18  0.6667  error_encoding_weight
# 19  0.6615  error_encoding_weight
# 20  0.4948   error_encoding_input
# 21  0.5260   error_encoding_input
# 22  0.5573   error_encoding_input
# 23  0.5208   error_encoding_input
# 24  0.5469   error_encoding_input
# 25  0.5417   error_encoding_input
# 26  0.4948   error_encoding_input
# 27  0.5052   error_encoding_input
# 28  0.4635   error_encoding_input
# 29  0.5573   error_encoding_input
# 30  0.4167          error_classic
# 31  0.4167          error_classic
# 32  0.4167          error_classic
# 33  0.4167          error_classic
# 34  0.4167          error_classic
# 35  0.4167          error_classic
# 36  0.4167          error_classic
# 37  0.4167          error_classic
# 38  0.4167          error_classic
# 39  0.4167          error_classic
# 40  0.3646      error_classic_bin
# 41  0.3646      error_classic_bin
# 42  0.3646      error_classic_bin
# 43  0.3646      error_classic_bin
# 44  0.3646      error_classic_bin
# 45  0.3646      error_classic_bin
# 46  0.3646      error_classic_bin
# 47  0.3646      error_classic_bin
# 48  0.3646      error_classic_bin
# 49  0.3646      error_classic_bin

# %%
df = pd.read_csv('results/HEALTH_ZERO_dataframe.csv')

# %%
np.mean(df[df.model == 'error_encoding_weight'])
# Out:
# error    0.36291
# dtype: float64

# %%
np.mean(df[df.model == 'error_encoding_input'])
# Out:
# error    0.480335
# dtype: float64

# %%
df2 = pd.read_csv('results/results_withoutbias_dataframe.csv')

# %%
np.mean(df2[df2.model == 'error_encoding_weight'])
# Out:
# error    0.573043
# dtype: float64

# %%
np.mean(df2[df2.model == 'error_encoding_input'])
# Out:
# error    0.493495
# dtype: float64
