# %%
from code.neuron import *
from code.encodingsource import *
from code.hsgs import *
from code.classical_neuron import *
from code.classical_pso import *
from code.sf import *
simulator = Aer.get_backend('qasm_simulator')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from code.experiment_functions import *

# %% [markdown]
# # Without Bias

# %%
with open('data/left_train.json') as json_file:
    train = json.load(json_file)
    
X_train = train['image']
y_train = train['flag']

# %%
epoch_errosHSGS, epoch_errosEncodingWeight, epoch_errosEncodingInput, epoch_errosPhaseEncoding  = experiment_TRAIN(train['image'], 
                                                                                                 train['flag'],
                                                                                                 lrParameter=0.2, 
                                                                                                 n_epochs=20, 
                                                                                                 trainingBias=True,
                                                                                                 error_by_epoch = True,
                                                                                                 trainingApproaches={'neuronio-classico', 
                                                                                                                     'neuronio-classico-bin', 
                                                                                                                     'hsgs',
                                                                                                                     'encoding-weight', 
                                                                                                                     'encoding-input',
                                                                                                                     'phase-encoding'})
# Out:
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.408203125
# erro phase encoding 0.9931640625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.408203125
# erro phase encoding 0.9736328125
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9736328125
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9736328125
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.96875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9677734375
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.9619140625
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.95703125
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.95703125
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.95703125
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.95703125
#
# erro HSGS 1.0
# erro encoding weight 0.587890625
# erro encoding input 0.3671875
# erro phase encoding 0.95703125

# %%
with open('results/version5/error_by_epoch_unbiased.json', 'w+') as fp:
    json.dump({'epoch_errosHSGS': epoch_errosHSGS,
               'epoch_errosEncodingWeight': epoch_errosEncodingWeight, 
               'epoch_errosPhaseEncoding': epoch_errosPhaseEncoding, 
               'epoch_errosEncodingInput': epoch_errosEncodingInput},
              fp)

# %%
weightsEncodingWeight, weightsEncodingInput, weightsPhaseEncoding, weightsHSGS = experiment_TRAIN(X_train, 
                                                                                                                                     y_train,
                                                                                                                                     lrParameter=0.2, 
                                                                                                                                     n_epochs=20, 
                                                                                                                                     trainingBias=False,
                                                                                                                                     error_by_epoch = False,
                                                                                                                                     trainingApproaches={'neuronio-classico', 
                                                                                                                                                         'neuronio-classico-bin', 
                                                                                                                                                         'hsgs',
                                                                                                                                                         'encoding-weight', 
                                                                                                                                                         'encoding-input',
                                                                                                                                                         'phase-encoding'})
# Out:
# erro HSGS 1.0
# erro encoding weight 0.9189453125
# erro encoding input 0.0048828125
# erro phase encoding 0.671875
#
# erro HSGS 1.0
# erro encoding weight 0.2568359375
# erro encoding input 0.0029296875
# erro phase encoding 0.6708984375
#
# erro HSGS 1.0
# erro encoding weight 0.240234375
# erro encoding input 0.0029296875
# erro phase encoding 0.6708984375
#
# erro HSGS 1.0
# erro encoding weight 0.240234375
# erro encoding input 0.0029296875
# erro phase encoding 0.6611328125
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.0029296875
# erro phase encoding 0.6611328125
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.65625
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.65625
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.65625
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375
#
# erro HSGS 1.0
# erro encoding weight 0.232421875
# erro encoding input 0.001953125
# erro phase encoding 0.646484375

# %%
weights = [weightsEncodingWeight, 
          weightsEncodingInput, 
          weightsPhaseEncoding, 
          weightsHSGS]

# %%
with open('results/version5/weights_unbiased_v5.json', 'w+') as fp:
    json.dump(weights, fp)

# %% [markdown]
# #### Test

# %%
with open('results/version5/weights_unbiased_v5.json') as json_file:
    weights = json.load(json_file)

# %%
with open('data/left_test.json') as json_file:
    test = json.load(json_file)
    
X_test = test['image']
y_test = test['flag']

# %%
resultsBIAS = experiment_TEST(X_test, 
                              y_test, 
                              weights[0], 
                              weights[1], 
                              weights[2], 
                              weights[3], 
                              repeat=10,
                              bias=False, 
                              testingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'phase-encoding','encoding-input'})
# Out:
# erro HSGS 0.5
# erro encoding weight 0.18
# erro encoding input 0.52
# erro phase encoding 0.62
# erro HSGS 0.5
# erro encoding weight 0.205
# erro encoding input 0.515
# erro phase encoding 0.615
# erro HSGS 0.5
# erro encoding weight 0.195
# erro encoding input 0.54
# erro phase encoding 0.6
# erro HSGS 0.5
# erro encoding weight 0.195
# erro encoding input 0.505
# erro phase encoding 0.615
# erro HSGS 0.5
# erro encoding weight 0.18
# erro encoding input 0.56
# erro phase encoding 0.61
# erro HSGS 0.5
# erro encoding weight 0.18
# erro encoding input 0.415
# erro phase encoding 0.61
# erro HSGS 0.5
# erro encoding weight 0.19
# erro encoding input 0.51
# erro phase encoding 0.62
# erro HSGS 0.5
# erro encoding weight 0.19
# erro encoding input 0.57
# erro phase encoding 0.61
# erro HSGS 0.5
# erro encoding weight 0.19
# erro encoding input 0.47
# erro phase encoding 0.615
# erro HSGS 0.5
# erro encoding weight 0.185
# erro encoding input 0.52
# erro phase encoding 0.615
# ERROS HSGS             0.5
# ERROS ENCODING WEIGHT  0.189
# ERROS ENCODING INPUT   0.5125
# ERROS PHASE ENCODING   0.6130000000000001

# %%
with open('results/version5/experiments_unbiased.json', 'w+') as fp:
    json.dump(resultsBIAS, fp)

# %%
def readAndResults(i):
    with open('results/'+i) as f:
        data = json.load(f)

    erros = ['error_HSGS', 'error_encoding_weight', 'error_encoding_input', 'error_phase_encoding']
    new_data = {'error':[], 'model':[]}

    for erro in erros:
        new_data['error'] = new_data['error'] + data[erro] 
        new_data['model'] = new_data['model'] +  ( (erro+' ') * len(data[erro])).split(' ')[:-1]  

    new_data = pd.DataFrame(new_data)

    new_data.to_csv('results/'+i[:-5]+'_dataframe.csv', index=False)
    
    return new_data

# %%
readAndResults('version5/experiments_unbiased.json')
# Out:
#     error                  model
# 0   0.500             error_HSGS
# 1   0.500             error_HSGS
# 2   0.500             error_HSGS
# 3   0.500             error_HSGS
# 4   0.500             error_HSGS
# 5   0.500             error_HSGS
# 6   0.500             error_HSGS
# 7   0.500             error_HSGS
# 8   0.500             error_HSGS
# 9   0.500             error_HSGS
# 10  0.180  error_encoding_weight
# 11  0.205  error_encoding_weight
# 12  0.195  error_encoding_weight
# 13  0.195  error_encoding_weight
# 14  0.180  error_encoding_weight
# 15  0.180  error_encoding_weight
# 16  0.190  error_encoding_weight
# 17  0.190  error_encoding_weight
# 18  0.190  error_encoding_weight
# 19  0.185  error_encoding_weight
# 20  0.520   error_encoding_input
# 21  0.515   error_encoding_input
# 22  0.540   error_encoding_input
# 23  0.505   error_encoding_input
# 24  0.560   error_encoding_input
# 25  0.415   error_encoding_input
# 26  0.510   error_encoding_input
# 27  0.570   error_encoding_input
# 28  0.470   error_encoding_input
# 29  0.520   error_encoding_input
# 30  0.620   error_phase_encoding
# 31  0.615   error_phase_encoding
# 32  0.600   error_phase_encoding
# 33  0.615   error_phase_encoding
# 34  0.610   error_phase_encoding
# 35  0.610   error_phase_encoding
# 36  0.620   error_phase_encoding
# 37  0.610   error_phase_encoding
# 38  0.615   error_phase_encoding
# 39  0.615   error_phase_encoding

# %% [markdown]
# ## BIAS

# %%
epoch_errosHSGS, epoch_errosEncodingWeight, epoch_errosEncodingInput, epoch_errosPhaseEncoding  = experiment_TRAIN(train['image'], 
                                                                                                 train['flag'],
                                                                                                 lrParameter=0.2, 
                                                                                                 n_epochs=20, 
                                                                                                 trainingBias=True,
                                                                                                 error_by_epoch = True,
                                                                                                 trainingApproaches={'neuronio-classico', 
                                                                                                                     'neuronio-classico-bin', 
                                                                                                                     'hsgs',
                                                                                                                     'encoding-weight', 
                                                                                                                     'encoding-input',
                                                                                                                     'phase-encoding'})
# Out:
# erro HSGS 1.0
# erro encoding weight 0.62109375
# erro encoding input 0.361328125
# erro phase encoding 0.9921875
#
# erro HSGS 1.0
# erro encoding weight 0.62109375
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.603515625
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.603515625
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6015625
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6015625
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6015625
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6015625
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.361328125
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.6005859375
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.5869140625
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.5869140625
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.5869140625
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.5869140625
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875
#
# erro HSGS 1.0
# erro encoding weight 0.5869140625
# erro encoding input 0.3603515625
# erro phase encoding 0.966796875

# %%
with open('results/version5/error_by_epoch_unbiased.json', 'w+') as fp:
    json.dump({'epoch_errosHSGS': epoch_errosHSGS,
               'epoch_errosEncodingWeight': epoch_errosEncodingWeight, 
               'epoch_errosPhaseEncoding': epoch_errosPhaseEncoding, 
               'epoch_errosEncodingInput': epoch_errosEncodingInput},
              fp)

# %%
weightsEncodingWeight, weightsEncodingInput, weightsPhaseEncoding, weightsHSGS  = experiment_TRAIN(X_train, 
                                                                                                                                     y_train,
                                                                                                                                     lrParameter=0.2, 
                                                                                                                                     n_epochs=20, 
                                                                                                                                     trainingBias=True,
                                                                                                                                     error_by_epoch = False,
                                                                                                                                     trainingApproaches={'neuronio-classico', 
                                                                                                                                                         'neuronio-classico-bin', 
                                                                                                                                                         'hsgs',
                                                                                                                                                         'encoding-weight', 
                                                                                                                                                         'encoding-input',
                                                                                                                                                         'phase-encoding'})
# Out:
# erro HSGS 1.0
# erro encoding weight 0.6279296875
# erro encoding input 0.3896484375
# erro phase encoding 0.98828125
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.3896484375
# erro phase encoding 0.9765625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.3896484375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.3896484375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.97265625
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.599609375
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.595703125
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.595703125
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.595703125
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.595703125
# erro encoding input 0.37109375
# erro phase encoding 0.9716796875
#
# erro HSGS 1.0
# erro encoding weight 0.595703125
# erro encoding input 0.37109375
# erro phase encoding 0.9697265625
#
# erro HSGS 1.0
# erro encoding weight 0.591796875
# erro encoding input 0.37109375
# erro phase encoding 0.9697265625
#
# erro HSGS 1.0
# erro encoding weight 0.591796875
# erro encoding input 0.37109375
# erro phase encoding 0.9697265625
#
# erro HSGS 1.0
# erro encoding weight 0.591796875
# erro encoding input 0.37109375
# erro phase encoding 0.9697265625
#
# erro HSGS 1.0
# erro encoding weight 0.591796875
# erro encoding input 0.37109375
# erro phase encoding 0.9697265625

# %%
weights = [weightsEncodingWeight, 
          weightsEncodingInput, 
          weightsPhaseEncoding, 
          weightsHSGS]

# %%
with open('results/version5/weights_biased_v5.json', 'w+') as fp:
    json.dump(weights, fp)

# %%
resultsBIAS = experiment_TEST(X_test, 
                              y_test, 
                              weights[0], 
                              weights[1], 
                              weights[2], 
                              weights[3], 
                              repeat=10,
                              bias=True, 
                              testingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'phase-encoding','encoding-input'})
# Out:
# erro HSGS 0.5
# erro encoding weight 0.16
# erro encoding input 0.56
# erro phase encoding 0.22
# erro HSGS 0.5
# erro encoding weight 0.165
# erro encoding input 0.465
# erro phase encoding 0.225
# erro HSGS 0.5
# erro encoding weight 0.165
# erro encoding input 0.47
# erro phase encoding 0.225
# erro HSGS 0.5
# erro encoding weight 0.17
# erro encoding input 0.5
# erro phase encoding 0.22
# erro HSGS 0.5
# erro encoding weight 0.155
# erro encoding input 0.485
# erro phase encoding 0.22
# erro HSGS 0.5
# erro encoding weight 0.17
# erro encoding input 0.525
# erro phase encoding 0.22
# erro HSGS 0.5
# erro encoding weight 0.165
# erro encoding input 0.47
# erro phase encoding 0.215
# erro HSGS 0.5
# erro encoding weight 0.17
# erro encoding input 0.485
# erro phase encoding 0.235
# erro HSGS 0.5
# erro encoding weight 0.165
# erro encoding input 0.54
# erro phase encoding 0.22
# erro HSGS 0.5
# erro encoding weight 0.175
# erro encoding input 0.555
# erro phase encoding 0.22
# ERROS HSGS             0.5
# ERROS ENCODING WEIGHT  0.166
# ERROS ENCODING INPUT   0.5055
# ERROS PHASE ENCODING   0.22199999999999998

# %%
with open('results/version5/experiments_biased.json', 'w+') as fp:
    json.dump(resultsBIAS, fp)

# %%
readAndResults('version5/experiments_biased.json')
# Out:
#     error                  model
# 0   0.500             error_HSGS
# 1   0.500             error_HSGS
# 2   0.500             error_HSGS
# 3   0.500             error_HSGS
# 4   0.500             error_HSGS
# 5   0.500             error_HSGS
# 6   0.500             error_HSGS
# 7   0.500             error_HSGS
# 8   0.500             error_HSGS
# 9   0.500             error_HSGS
# 10  0.160  error_encoding_weight
# 11  0.165  error_encoding_weight
# 12  0.165  error_encoding_weight
# 13  0.170  error_encoding_weight
# 14  0.155  error_encoding_weight
# 15  0.170  error_encoding_weight
# 16  0.165  error_encoding_weight
# 17  0.170  error_encoding_weight
# 18  0.165  error_encoding_weight
# 19  0.175  error_encoding_weight
# 20  0.560   error_encoding_input
# 21  0.465   error_encoding_input
# 22  0.470   error_encoding_input
# 23  0.500   error_encoding_input
# 24  0.485   error_encoding_input
# 25  0.525   error_encoding_input
# 26  0.470   error_encoding_input
# 27  0.485   error_encoding_input
# 28  0.540   error_encoding_input
# 29  0.555   error_encoding_input
# 30  0.220   error_phase_encoding
# 31  0.225   error_phase_encoding
# 32  0.225   error_phase_encoding
# 33  0.220   error_phase_encoding
# 34  0.220   error_phase_encoding
# 35  0.220   error_phase_encoding
# 36  0.215   error_phase_encoding
# 37  0.235   error_phase_encoding
# 38  0.220   error_phase_encoding
# 39  0.220   error_phase_encoding
