# %%
from code.neuron import *
from code.encodingsource import *
from code.hsgs import *
from code.classical_neuron import *
from code.classical_pso import *
from code.sf import *
simulator = Aer.get_backend('qasm_simulator')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from code.experiment_functions import *

# %%
diabetes = pd.read_csv('data/diabetes.csv')

# %%
# normalization 0-1
for i in diabetes.columns:
    diabetes[i] = (diabetes[i] - diabetes[i].min()) / (diabetes[i].max() - diabetes[i].min())

# %%
# split in test and train data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(diabetes.drop('Outcome',axis=1), diabetes['Outcome'])

# %%
X_train = X_train.values.tolist()
X_test = X_test.values.tolist()
y_train = y_train.values.tolist()
y_test = y_test.values.tolist()

# %%
y_train = [int(x) for x in y_train]
y_test =  [int(x) for x in y_test]

# %% [markdown]
# ### Train and Test with Bias

# %%
epoch_errosHSGS, epoch_errosEncodingWeight, epoch_errosEncodingInput, epoch_errosPhaseEncoding  = experiment_TRAIN(X_train, 
                                                                                                 y_train,
                                                                                                 lrParameter=0.2, 
                                                                                                 n_epochs=20, 
                                                                                                 trainingBias=True,
                                                                                                 error_by_epoch = True,
                                                                                                 trainingApproaches={'neuronio-classico', 
                                                                                                                     'neuronio-classico-bin', 
                                                                                                                     'hsgs',
                                                                                                                     'encoding-weight', 
                                                                                                                     'encoding-input',
                                                                                                                     'phase-encoding'})
# Out:
# erro HSGS 8.2080078125
# erro encoding weight 331.734375
# erro encoding input 182.505859375
# erro phase encoding 73.08203125
# erro classico 21.800604746665947
# erro classico Bin 150.1796233262912
#
# erro HSGS 0.0
# erro encoding weight 330.5244140625
# erro encoding input 181.1201171875
# erro phase encoding 74.41796875
# erro classico 11.836733653224373
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.3505859375
# erro encoding input 181.453125
# erro phase encoding 73.609375
# erro classico 11.83895421034015
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.5224609375
# erro encoding input 181.1103515625
# erro phase encoding 73.7763671875
# erro classico 11.839079572712958
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.404296875
# erro encoding input 180.865234375
# erro phase encoding 74.19921875
# erro classico 11.839084109064341
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.9736328125
# erro encoding input 181.4404296875
# erro phase encoding 74.2890625
# erro classico 11.839084278300644
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.6796875
# erro encoding input 181.087890625
# erro phase encoding 73.935546875
# erro classico 11.839084284865777
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.4775390625
# erro encoding input 181.20703125
# erro phase encoding 73.919921875
# erro classico 11.839084285105224
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.9609375
# erro encoding input 181.1435546875
# erro phase encoding 74.1494140625
# erro classico 11.83908428512826
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.087890625
# erro encoding input 181.4619140625
# erro phase encoding 73.75390625
# erro classico 11.839084285138629
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.8984375
# erro encoding input 181.3291015625
# erro phase encoding 73.84375
# erro classico 11.839084285138169
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.02734375
# erro encoding input 181.5224609375
# erro phase encoding 74.2587890625
# erro classico 11.839084285139236
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.3076171875
# erro encoding input 181.3837890625
# erro phase encoding 73.7314453125
# erro classico 11.839084285138169
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.291015625
# erro encoding input 181.88671875
# erro phase encoding 73.8154296875
# erro classico 11.839084285139236
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.876953125
# erro encoding input 181.0859375
# erro phase encoding 73.677734375
# erro classico 11.839084285138169
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.7001953125
# erro encoding input 181.5
# erro phase encoding 73.7412109375
# erro classico 11.839084285139236
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.43359375
# erro encoding input 181.2783203125
# erro phase encoding 73.8642578125
# erro classico 11.839084285138169
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.9296875
# erro encoding input 181.9814453125
# erro phase encoding 73.2880859375
# erro classico 11.839084285139236
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.322265625
# erro encoding input 181.05078125
# erro phase encoding 73.5234375
# erro classico 11.839084285138169
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.615234375
# erro encoding input 181.5078125
# erro phase encoding 73.791015625
# erro classico 11.839084285139236
# erro classico Bin 145.7823554784469

# %%
with open('results/version4/error_by_epoch_biased.json', 'w+') as fp:
    json.dump({'epoch_errosHSGS': epoch_errosHSGS,
               'epoch_errosEncodingWeight': epoch_errosEncodingWeight, 
               'epoch_errosPhaseEncoding': epoch_errosPhaseEncoding, 
               'epoch_errosEncodingInput': epoch_errosEncodingInput},
              fp)

# %%
weightsEncodingWeight, weightsEncodingInput, weightsPhaseEncoding, weightsHSGS, weightsVectorsClassico, weightVectorsClassicoBin = experiment_TRAIN(X_train, 
                                                                                                             y_train,
                                                                                                             lrParameter=0.2, 
                                                                                                             n_epochs=10, 
                                                                                                             trainingBias=True,
                                                                                                             trainingApproaches={'neuronio-classico', 
                                                                                                                                 'neuronio-classico-bin', 
                                                                                                                                 'hsgs',
                                                                                                                                 'encoding-weight', 
                                                                                                                                 'encoding-input', 
                                                                                                                                 'phase-encoding'})
# Out:
# erro HSGS 8.16796875
# erro encoding weight 331.76953125
# erro encoding input 182.234375
# erro phase encoding 72.578125
# erro classico 21.800604746665947
# erro classico Bin 150.1796233262912
#
# erro HSGS 0.0
# erro encoding weight 331.6689453125
# erro encoding input 181.330078125
# erro phase encoding 73.822265625
# erro classico 11.836733653224373
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.4013671875
# erro encoding input 181.201171875
# erro phase encoding 74.1748046875
# erro classico 11.83895421034015
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.37109375
# erro encoding input 181.494140625
# erro phase encoding 73.64453125
# erro classico 11.839079572712958
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.25390625
# erro encoding input 181.5771484375
# erro phase encoding 74.015625
# erro classico 11.839084109064341
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.953125
# erro encoding input 180.77734375
# erro phase encoding 74.107421875
# erro classico 11.839084278300644
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 331.265625
# erro encoding input 181.2451171875
# erro phase encoding 73.939453125
# erro classico 11.839084284865777
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.5986328125
# erro encoding input 180.828125
# erro phase encoding 73.60546875
# erro classico 11.839084285105224
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.447265625
# erro encoding input 180.5849609375
# erro phase encoding 74.212890625
# erro classico 11.83908428512826
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.9345703125
# erro encoding input 181.583984375
# erro phase encoding 73.779296875
# erro classico 11.839084285138629
# erro classico Bin 145.7823554784469
#
# erro HSGS 0.0
# erro encoding weight 330.9345703125
# erro encoding input 181.583984375
# erro phase encoding 73.779296875
# erro Classico 11.839084285138629
# erro classico Bin 145.7823554784469

# %%
weights = [weightsEncodingWeight, 
          weightsEncodingInput, 
          weightsPhaseEncoding, 
          weightsHSGS, 
          weightsVectorsClassico, 
          weightVectorsClassicoBin]

# %%
with open('results/version4/weights_biased_v4.json', 'w+') as fp:
    json.dump(weights, fp)

# %% [markdown]
# #### Test

# %%
with open('results/version4/weights_biased_v4.json') as json_file:
    weights = json.load(json_file)

# %%
resultsBIAS = experiment_TEST(X_test, 
                              y_test, 
                              weights[0], 
                              weights[1], 
                              weights[2], 
                              weights[3], 
                              weights[4], 
                              weights[5], 
                              repeat=10,
                              bias=True, 
                              testingApproaches={'neuronio-classico', 'neuronio-classico-bin', 'hsgs','encoding-weight', 'phase-encoding','encoding-input'})
# Out:
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3541666666666667
# erro encoding input 0.5989583333333334
# erro phase encoding 0.484375
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3541666666666667
# erro encoding input 0.5520833333333334
# erro phase encoding 0.4791666666666667
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3541666666666667
# erro encoding input 0.4583333333333333
# erro phase encoding 0.4791666666666667
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3541666666666667
# erro encoding input 0.421875
# erro phase encoding 0.4739583333333333
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.359375
# erro encoding input 0.5208333333333334
# erro phase encoding 0.4739583333333333
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3645833333333333
# erro encoding input 0.46875
# erro phase encoding 0.484375
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.359375
# erro encoding input 0.4895833333333333
# erro phase encoding 0.4895833333333333
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.359375
# erro encoding input 0.4895833333333333
# erro phase encoding 0.4791666666666667
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3645833333333333
# erro encoding input 0.5
# erro phase encoding 0.4739583333333333
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# erro HSGS 0.3645833333333333
# erro encoding weight 0.3697916666666667
# erro encoding input 0.5
# erro phase encoding 0.4895833333333333
# erro classico 0.2760416666666667
# erro classico bin 0.3645833333333333
# ERROS HSGS             0.3645999999999999
# ERROS ENCODING WEIGHT  0.35940000000000005
# ERROS ENCODING INPUT   0.50001
# ERROS PHASE ENCODING   0.4807600000000001
# ERROS Classico         0.27599999999999997
# ERROS Classico Bin     0.3645999999999999

# %%
with open('results/version4/experiments_biased.json', 'w+') as fp:
    json.dump(resultsBIAS, fp)

# %% [markdown]
# ## Save results as dataframe

# %%
resultsBIAS
# Out:
# {'error_HSGS': [0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646],
#  'error_encoding_weight': [0.3542,
#   0.3542,
#   0.3542,
#   0.3542,
#   0.3594,
#   0.3646,
#   0.3594,
#   0.3594,
#   0.3646,
#   0.3698],
#  'error_encoding_input': [0.599,
#   0.5521,
#   0.4583,
#   0.4219,
#   0.5208,
#   0.4688,
#   0.4896,
#   0.4896,
#   0.5,
#   0.5],
#  'error_phase_encoding': [0.4844,
#   0.4792,
#   0.4792,
#   0.474,
#   0.474,
#   0.4844,
#   0.4896,
#   0.4792,
#   0.474,
#   0.4896],
#  'error_classic': [0.276,
#   0.276,
#   0.276,
#   0.276,
#   0.276,
#   0.276,
#   0.276,
#   0.276,
#   0.276,
#   0.276],
#  'error_classic_bin': [0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646,
#   0.3646],
#  'weights_learned_HSGS': [[-0.228236223846,
#    -0.030962467201,
#    -0.29250077801,
#    -0.208384895873,
#    -0.172454409066,
#    -0.248492541032,
#    -0.198619188027,
#    -0.215874073364,
#    -0.386730751038,
#    -0.102695694937,
#    -0.386730751038,
#    -0.102695694937,
#    -0.386730751038,
#    -0.102695694937,
#    -0.386730751038,
#    -0.102695694937],
#   [-0.139757479571,
#    -0.185868724824,
#    -0.205246005649,
#    -0.09250412379,
#    -0.002626604209,
#    -0.136690839915,
#    -0.094576808126,
#    -0.063914750291,
#    -0.290347776062,
#    -0.290347776062,
#    -0.349459892516,
#    -0.349459892516,
#    -0.349459892516,
#    -0.290347776062,
#    -0.349459892516,
#    -0.349459892516]],
#  'weights_learned_encoding_weight': [[-0.032051887991,
#    -0.162687104329,
#    -0.180443938116,
#    -0.03173980226,
#    -0.006023886809,
#    -0.132443439419,
#    -0.043834448822,
#    -0.07707771286,
#    -0.337916070965,
#    -0.337916070965,
#    -0.337916070965,
#    -0.337916070965,
#    -0.337916070965,
#    -0.337916070965,
#    -0.090033347963,
#    -0.024209631657,
#    -0.166444190121,
#    -0.060692088415,
#    -0.079527474804,
#    -0.329854087588,
#    -0.329854087588,
#    -0.329854087588,
#    -0.329854087588,
#    -0.329854087588,
#    -0.329854087588,
#    -0.329854087588,
#    -0.329854087588]]}

# %%
def readAndResults(i):
    with open('results/'+i) as f:
        data = json.load(f)

    erros = ['error_HSGS', 'error_encoding_weight', 'error_encoding_input', 'error_classic', 'error_classic_bin']
    new_data = {'error':[], 'model':[]}

    for erro in erros:
        new_data['error'] = new_data['error'] + data[erro] 
        new_data['model'] = new_data['model'] +  ( (erro+' ') * len(data[erro])).split(' ')[:-1]  

    new_data = pd.DataFrame(new_data)

    new_data.to_csv('results/'+i[:-5]+'_dataframe.csv', index=False)
    
    return new_data

# %%
readAndResults('version4/experiments_biased.json')
# Out:
#      error                  model
# 0   0.3646             error_HSGS
# 1   0.3646             error_HSGS
# 2   0.3646             error_HSGS
# 3   0.3646             error_HSGS
# 4   0.3646             error_HSGS
# 5   0.3646             error_HSGS
# 6   0.3646             error_HSGS
# 7   0.3646             error_HSGS
# 8   0.3646             error_HSGS
# 9   0.3646             error_HSGS
# 10  0.3542  error_encoding_weight
# 11  0.3542  error_encoding_weight
# 12  0.3542  error_encoding_weight
# 13  0.3542  error_encoding_weight
# 14  0.3594  error_encoding_weight
# 15  0.3646  error_encoding_weight
# 16  0.3594  error_encoding_weight
# 17  0.3594  error_encoding_weight
# 18  0.3646  error_encoding_weight
# 19  0.3698  error_encoding_weight
# 20  0.5990   error_encoding_input
# 21  0.5521   error_encoding_input
# 22  0.4583   error_encoding_input
# 23  0.4219   error_encoding_input
# 24  0.5208   error_encoding_input
# 25  0.4688   error_encoding_input
# 26  0.4896   error_encoding_input
# 27  0.4896   error_encoding_input
# 28  0.5000   error_encoding_input
# 29  0.5000   error_encoding_input
# 30  0.2760          error_classic
# 31  0.2760          error_classic
# 32  0.2760          error_classic
# 33  0.2760          error_classic
# 34  0.2760          error_classic
# 35  0.2760          error_classic
# 36  0.2760          error_classic
# 37  0.2760          error_classic
# 38  0.2760          error_classic
# 39  0.2760          error_classic
# 40  0.3646      error_classic_bin
# 41  0.3646      error_classic_bin
# 42  0.3646      error_classic_bin
# 43  0.3646      error_classic_bin
# 44  0.3646      error_classic_bin
# 45  0.3646      error_classic_bin
# 46  0.3646      error_classic_bin
# 47  0.3646      error_classic_bin
# 48  0.3646      error_classic_bin
# 49  0.3646      error_classic_bin

# %%
df = pd.read_csv('results/HEALTH_ZERO_dataframe.csv')

# %%
np.mean(df[df.model == 'error_encoding_weight'])
# Out:
# error    0.36291
# dtype: float64

# %%
np.mean(df[df.model == 'error_encoding_input'])
# Out:
# error    0.480335
# dtype: float64

# %%
df2 = pd.read_csv('results/results_withoutbias_dataframe.csv')

# %%
np.mean(df2[df2.model == 'error_encoding_weight'])
# Out:
# error    0.573043
# dtype: float64

# %%
np.mean(df2[df2.model == 'error_encoding_input'])
# Out:
# error    0.493495
# dtype: float64
